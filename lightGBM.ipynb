# %% [markdown]
# # Intro

# %%
import pandas as pd
import numpy as np
import random
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.metrics import fbeta_score, make_scorer
from sklearn.model_selection import train_test_split
from imblearn.pipeline import make_pipeline, Pipeline
from imblearn.under_sampling import EditedNearestNeighbours # resampling
from imblearn.combine import SMOTEENN # resampling
from lightgbm import LGBMClassifier
import optuna


# Set metric
def f2_measure(y_true, y_pred):
    return fbeta_score(y_true, y_pred, beta=2)
f2_score = make_scorer(f2_measure) 

# Set seeds
seeds = 1234
def set_seeds(seed=seeds):
    """Set seeds for reproducibility."""
    np.random.seed(seed)
    random.seed(seed)
set_seeds()

# Set k-fold cross-validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seeds)

# Load data
df = pd.read_pickle(r"train_enc.pkl")
test = pd.read_pickle(r"test_enc.pkl")

# Separate labels and target
X, y =  df.drop(columns="left", axis = 1), df["left"]
X_test, y_test =  test.drop(columns="left", axis = 1), test["left"]

# %%
# Get variable names
bi_vars = [col for col in X.columns if X[col].nunique() == 2]
num_vars = [col for col in X.columns if (X[col].dtype in ["int8", "float32"]) & (col not in bi_vars)]
cat_vars = [col for col in X.columns if (col not in num_vars) & (col not in bi_vars)]

# Preprocessing
preprocess = ColumnTransformer(
    transformers=[
        ("scaler", MinMaxScaler(), num_vars),
        ("ohe", OneHotEncoder(), cat_vars)
    ], remainder = "passthrough"
)

# Resampling 
smoteen = SMOTEENN(enn=EditedNearestNeighbours(sampling_strategy='majority'), random_state=seeds)

# %%
        "objective": "binary",
        "metric": "auc",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),

# %%
def objective(trial):
    params = {
            'n_estimators':trial.suggest_int("n_estimators", 1000, 10000),
            'learning_rate' : trial.suggest_uniform('learning_rate', 0.001, 1),
            'subsample': trial.suggest_uniform('subsample', 0.1, 1),
            'colsample_bytree':trial.suggest_uniform('colsample_bytree', 0.1, 1),
            'max_depth': trial.suggest_categorical('max_depth', [1,3,5,7,9,11,13,15,17,20]),
            'min_child_weight': trial.suggest_int('min_child_weight', 1, 300),
            'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-5, 10.0),
            'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-5, 10.0),
                    "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
    }
    clf = LGBMClassifier(random_state=seeds,**params)
    model = make_pipeline(preprocess, smoteen, clf)
    # Evaluate model
    scores = cross_val_score(model, X, y, scoring=f2_score, cv=cv, n_jobs=-1).mean()
    return scores

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=150)
best_params = study.best_trial.params
print('Number of finished trials:', len(study.trials))
print('Best trial:', best_params)
# Out:
# [I 2022-02-19 14:29:59,218] A new study created in memory with name: no-name-15cafc6b-bb4c-4ed2-899a-b0487df7d6df
# [I 2022-02-19 14:30:10,547] Trial 0 finished with value: 0.8053544325797664 and parameters: {'n_estimators': 2583, 'learning_rate': 0.07977498779003575, 'subsample': 0.5289339175079663, 'colsample_bytree': 0.5915782813759934, 'max_depth': 20, 'min_child_weight': 93, 'reg_lambda': 1.600534709959207e-05, 'reg_alpha': 0.00029582691007067334, 'lambda_l1': 1.1763767266706047e-05, 'lambda_l2': 0.31540746902593436, 'num_leaves': 49}. Best is trial 0 with value: 0.8053544325797664.
# [I 2022-02-19 14:30:17,778] Trial 1 finished with value: 0.7721911568860038 and parameters: {'n_estimators': 1492, 'learning_rate': 0.15234817001373335, 'subsample': 0.8462380275471618, 'colsample_bytree': 0.6171227964443432, 'max_depth': 9, 'min_child_weight': 250, 'reg_lambda': 0.2965512973537026, 'reg_alpha': 8.953418274166719, 'lambda_l1': 0.0165456324958619, 'lambda_l2': 0.005708855136731613, 'num_leaves': 17}. Best is trial 0 with value: 0.8053544325797664.
# [I 2022-02-19 14:30:26,540] Trial 2 finished with value: 0.8132783253695198 and parameters: {'n_estimators': 9050, 'learning_rate': 0.5240405513995452, 'subsample': 0.43543395393175777, 'colsample_bytree': 0.49351524379533873, 'max_depth': 13, 'min_child_weight': 20, 'reg_lambda': 0.40781788159992716, 'reg_alpha': 7.084433855004426e-05, 'lambda_l1': 1.4270901943703156, 'lambda_l2': 0.00903814156922305, 'num_leaves': 115}. Best is trial 2 with value: 0.8132783253695198.
# [I 2022-02-19 14:30:37,634] Trial 3 finished with value: 0.7802732333758797 and parameters: {'n_estimators': 7477, 'learning_rate': 0.6813317258535955, 'subsample': 0.6096034126445488, 'colsample_bytree': 0.871080544020252, 'max_depth': 5, 'min_child_weight': 187, 'reg_lambda': 0.0006587218165618967, 'reg_alpha': 3.084173443265245, 'lambda_l1': 0.27254798505085587, 'lambda_l2': 1.279509709595642, 'num_leaves': 62}. Best is trial 2 with value: 0.8132783253695198.
# [I 2022-02-19 14:30:45,500] Trial 4 finished with value: 0.8003138764732778 and parameters: {'n_estimators': 4475, 'learning_rate': 0.3618895075492833, 'subsample': 0.8694738677396371, 'colsample_bytree': 0.7630128001280101, 'max_depth': 11, 'min_child_weight': 105, 'reg_lambda': 0.0033450761387054796, 'reg_alpha': 0.0028382279137398898, 'lambda_l1': 0.0019028140560178606, 'lambda_l2': 0.029164709626682453, 'num_leaves': 205}. Best is trial 2 with value: 0.8132783253695198.
# [I 2022-02-19 14:30:53,196] Trial 5 finished with value: 0.7853913547100384 and parameters: {'n_estimators': 4723, 'learning_rate': 0.9378867269502147, 'subsample': 0.27995864466517645, 'colsample_bytree': 0.9740447911795976, 'max_depth': 13, 'min_child_weight': 153, 'reg_lambda': 0.2404178883884261, 'reg_alpha': 0.2606246880323396, 'lambda_l1': 1.9118214033711624e-05, 'lambda_l2': 2.502850586753195e-06, 'num_leaves': 184}. Best is trial 2 with value: 0.8132783253695198.
# [I 2022-02-19 14:31:01,659] Trial 6 finished with value: 0.801942181452182 and parameters: {'n_estimators': 4692, 'learning_rate': 0.5937108592690054, 'subsample': 0.9022489853590416, 'colsample_bytree': 0.7578774718142113, 'max_depth': 15, 'min_child_weight': 75, 'reg_lambda': 0.0011928706820702494, 'reg_alpha': 0.007877085247984222, 'lambda_l1': 3.4550927447436835e-05, 'lambda_l2': 0.06600984603290178, 'num_leaves': 204}. Best is trial 2 with value: 0.8132783253695198.
# [I 2022-02-19 14:31:12,228] Trial 7 finished with value: 0.7510074311346541 and parameters: {'n_estimators': 6680, 'learning_rate': 0.7992386359993635, 'subsample': 0.36269624025135727, 'colsample_bytree': 0.3567924361085545, 'max_depth': 15, 'min_child_weight': 293, 'reg_lambda': 0.00357332648076818, 'reg_alpha': 0.0383208637689392, 'lambda_l1': 0.06367856944712313, 'lambda_l2': 4.90931568570974e-06, 'num_leaves': 198}. Best is trial 2 with value: 0.8132783253695198.
# [I 2022-02-19 14:31:27,072] Trial 8 finished with value: 0.777382502924423 and parameters: {'n_estimators': 9295, 'learning_rate': 0.821944382775472, 'subsample': 0.9982904796979061, 'colsample_bytree': 0.331920084184536, 'max_depth': 11, 'min_child_weight': 159, 'reg_lambda': 0.0018707450372781916, 'reg_alpha': 0.0008503877089092767, 'lambda_l1': 0.0008390483105473408, 'lambda_l2': 5.647804668361591, 'num_leaves': 127}. Best is trial 2 with value: 0.8132783253695198.
# [I 2022-02-19 14:31:34,285] Trial 9 finished with value: 0.7626030553178336 and parameters: {'n_estimators': 4187, 'learning_rate': 0.7108792607602163, 'subsample': 0.4760769096150843, 'colsample_bytree': 0.28593570150488506, 'max_depth': 7, 'min_child_weight': 241, 'reg_lambda': 0.00012788446652096938, 'reg_alpha': 0.019712580168591478, 'lambda_l1': 1.6715123713199893e-05, 'lambda_l2': 7.877220006662425e-05, 'num_leaves': 220}. Best is trial 2 with value: 0.8132783253695198.
# [I 2022-02-19 14:31:53,969] Trial 10 finished with value: 0.7984829281644494 and parameters: {'n_estimators': 9748, 'learning_rate': 0.4151787902833956, 'subsample': 0.11008686015337199, 'colsample_bytree': 0.15111961726404716, 'max_depth': 17, 'min_child_weight': 2, 'reg_lambda': 5.05156551180544, 'reg_alpha': 1.3414738470866702e-05, 'lambda_l1': 1.082423973283963e-08, 'lambda_l2': 3.098778072549649e-08, 'num_leaves': 134}. Best is trial 2 with value: 0.8132783253695198.
# [I 2022-02-19 14:32:00,449] Trial 11 finished with value: 0.8163231166381738 and parameters: {'n_estimators': 1684, 'learning_rate': 0.014780228829859549, 'subsample': 0.6650864205825331, 'colsample_bytree': 0.5144583637633943, 'max_depth': 20, 'min_child_weight': 9, 'reg_lambda': 2.325254980979303e-05, 'reg_alpha': 9.468913316737763e-05, 'lambda_l1': 2.950898006952111, 'lambda_l2': 0.0009642036970601606, 'num_leaves': 80}. Best is trial 11 with value: 0.8163231166381738.
# [I 2022-02-19 14:32:12,227] Trial 12 finished with value: 0.7963632474716874 and parameters: {'n_estimators': 7832, 'learning_rate': 0.24748150522226103, 'subsample': 0.6874650407875447, 'colsample_bytree': 0.4486983839200008, 'max_depth': 1, 'min_child_weight': 4, 'reg_lambda': 0.07520039115690097, 'reg_alpha': 3.707749249552061e-05, 'lambda_l1': 9.529073639876357, 'lambda_l2': 0.0015132338722543507, 'num_leaves': 111}. Best is trial 11 with value: 0.8163231166381738.
# [I 2022-02-19 14:32:16,525] Trial 13 finished with value: 0.8096919887993046 and parameters: {'n_estimators': 2881, 'learning_rate': 0.4836936969041991, 'subsample': 0.7067933030864306, 'colsample_bytree': 0.5294263550626405, 'max_depth': 13, 'min_child_weight': 55, 'reg_lambda': 0.03053461679066591, 'reg_alpha': 8.225622082211544e-05, 'lambda_l1': 9.553713124190935, 'lambda_l2': 0.0001420282567412811, 'num_leaves': 87}. Best is trial 11 with value: 0.8163231166381738.
# [I 2022-02-19 14:32:31,101] Trial 14 finished with value: 0.8183553899612376 and parameters: {'n_estimators': 6120, 'learning_rate': 0.006401239573091163, 'subsample': 0.39486946892386104, 'colsample_bytree': 0.6804123159992105, 'max_depth': 20, 'min_child_weight': 40, 'reg_lambda': 4.762312085649279, 'reg_alpha': 0.00020418494397091467, 'lambda_l1': 0.9169981222301926, 'lambda_l2': 0.001507169554771348, 'num_leaves': 159}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:32:47,045] Trial 15 finished with value: 0.814204264555437 and parameters: {'n_estimators': 6086, 'learning_rate': 0.003117546962359016, 'subsample': 0.18326785989239452, 'colsample_bytree': 0.7068216794931257, 'max_depth': 20, 'min_child_weight': 36, 'reg_lambda': 5.95033044946907, 'reg_alpha': 0.0005332601039954211, 'lambda_l1': 0.34744143646799863, 'lambda_l2': 1.285127122953196e-05, 'num_leaves': 168}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:32:53,442] Trial 16 finished with value: 0.803933234519451 and parameters: {'n_estimators': 3383, 'learning_rate': 0.22817788209152573, 'subsample': 0.3282458443853761, 'colsample_bytree': 0.6646678963847215, 'max_depth': 20, 'min_child_weight': 110, 'reg_lambda': 4.922690227194378e-05, 'reg_alpha': 0.0019427770224238836, 'lambda_l1': 0.015209496770966759, 'lambda_l2': 0.001513372264076397, 'num_leaves': 246}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:33:06,834] Trial 17 finished with value: 0.8171766709991843 and parameters: {'n_estimators': 5593, 'learning_rate': 0.009258516366195435, 'subsample': 0.6328718380700233, 'colsample_bytree': 0.839167159202922, 'max_depth': 20, 'min_child_weight': 42, 'reg_lambda': 1.370372213214282, 'reg_alpha': 0.00018153336226297515, 'lambda_l1': 3.8830704410213474e-08, 'lambda_l2': 2.0047977165198675e-07, 'num_leaves': 159}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:33:17,149] Trial 18 finished with value: 0.8105752031951091 and parameters: {'n_estimators': 5627, 'learning_rate': 0.2972022402285248, 'subsample': 0.57316590420015, 'colsample_bytree': 0.8685160205741991, 'max_depth': 3, 'min_child_weight': 59, 'reg_lambda': 1.3736065935455892, 'reg_alpha': 1.3666973800665553e-05, 'lambda_l1': 1.1799031015937233e-08, 'lambda_l2': 1.4875369627020185e-08, 'num_leaves': 156}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:33:29,259] Trial 19 finished with value: 0.7998119710017946 and parameters: {'n_estimators': 7103, 'learning_rate': 0.14716907654573427, 'subsample': 0.7461215651512421, 'colsample_bytree': 0.9849520923062346, 'max_depth': 20, 'min_child_weight': 122, 'reg_lambda': 1.324909312225263, 'reg_alpha': 0.07985106202275684, 'lambda_l1': 3.6069855563798987e-07, 'lambda_l2': 1.0024819226590538e-07, 'num_leaves': 158}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:33:38,980] Trial 20 finished with value: 0.7751594907753161 and parameters: {'n_estimators': 6046, 'learning_rate': 0.12085430176524906, 'subsample': 0.41367268690258785, 'colsample_bytree': 0.8452885958137165, 'max_depth': 7, 'min_child_weight': 195, 'reg_lambda': 0.017638528607908995, 'reg_alpha': 0.00031736883839395756, 'lambda_l1': 3.949428048763078e-07, 'lambda_l2': 2.126742213074748e-06, 'num_leaves': 249}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:33:44,153] Trial 21 finished with value: 0.8143146571667664 and parameters: {'n_estimators': 1431, 'learning_rate': 0.005653767485484696, 'subsample': 0.6277360617761836, 'colsample_bytree': 0.44316714830800263, 'max_depth': 20, 'min_child_weight': 36, 'reg_lambda': 9.094201717952181, 'reg_alpha': 0.00014634968857009408, 'lambda_l1': 1.453305271106622, 'lambda_l2': 0.0003844129750670603, 'num_leaves': 98}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:33:59,113] Trial 22 finished with value: 0.8124559521247864 and parameters: {'n_estimators': 8054, 'learning_rate': 0.05351456075180169, 'subsample': 0.780092091020122, 'colsample_bytree': 0.797348745156864, 'max_depth': 20, 'min_child_weight': 65, 'reg_lambda': 1.3385616290562556, 'reg_alpha': 3.253564150067404e-05, 'lambda_l1': 0.0001712398733577539, 'lambda_l2': 2.936848559201739e-07, 'num_leaves': 74}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:34:10,440] Trial 23 finished with value: 0.8025329790498889 and parameters: {'n_estimators': 5383, 'learning_rate': 0.21236209105640091, 'subsample': 0.4988680521457924, 'colsample_bytree': 0.6600354526547041, 'max_depth': 20, 'min_child_weight': 34, 'reg_lambda': 0.08367306203471678, 'reg_alpha': 0.0016448560342963812, 'lambda_l1': 7.307488528415645e-07, 'lambda_l2': 3.3393042683585186e-05, 'num_leaves': 144}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:34:21,961] Trial 24 finished with value: 0.8136588441612972 and parameters: {'n_estimators': 6549, 'learning_rate': 0.08463894231277669, 'subsample': 0.6581719396852186, 'colsample_bytree': 0.5579932860725028, 'max_depth': 9, 'min_child_weight': 83, 'reg_lambda': 0.00031636143209968977, 'reg_alpha': 0.00017866572554489952, 'lambda_l1': 0.003592956231185886, 'lambda_l2': 0.0007585912689102882, 'num_leaves': 36}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:34:31,149] Trial 25 finished with value: 0.8038400752930105 and parameters: {'n_estimators': 3695, 'learning_rate': 0.16673910474902875, 'subsample': 0.24473282976154004, 'colsample_bytree': 0.9185449057030537, 'max_depth': 17, 'min_child_weight': 20, 'reg_lambda': 2.9490745998784726, 'reg_alpha': 0.003946086141654072, 'lambda_l1': 0.11572942583129747, 'lambda_l2': 0.00887356595875498, 'num_leaves': 177}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:34:39,328] Trial 26 finished with value: 0.7820005331944877 and parameters: {'n_estimators': 5527, 'learning_rate': 0.008869267967684134, 'subsample': 0.5585889113735917, 'colsample_bytree': 0.7335437852814796, 'max_depth': 1, 'min_child_weight': 131, 'reg_lambda': 0.4592438692280959, 'reg_alpha': 0.0008359827560297433, 'lambda_l1': 1.0192904428138365, 'lambda_l2': 7.150845705775539e-07, 'num_leaves': 98}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:34:44,460] Trial 27 finished with value: 0.8088967510740247 and parameters: {'n_estimators': 2074, 'learning_rate': 0.3082352653989351, 'subsample': 0.7645362461111532, 'colsample_bytree': 0.6815998136850564, 'max_depth': 5, 'min_child_weight': 48, 'reg_lambda': 1.8073144292443677e-05, 'reg_alpha': 6.127232942661346e-05, 'lambda_l1': 0.025348924643118602, 'lambda_l2': 2.273942766954346e-05, 'num_leaves': 142}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:35:04,866] Trial 28 finished with value: 0.8147612641493325 and parameters: {'n_estimators': 8218, 'learning_rate': 0.07621293043612136, 'subsample': 0.3857538115040525, 'colsample_bytree': 0.8146362033401255, 'max_depth': 20, 'min_child_weight': 1, 'reg_lambda': 0.0064075845794775415, 'reg_alpha': 1.0075276244013652e-05, 'lambda_l1': 9.023178083565993e-08, 'lambda_l2': 0.06505412127673565, 'num_leaves': 75}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:35:14,129] Trial 29 finished with value: 0.8125439726111375 and parameters: {'n_estimators': 5126, 'learning_rate': 0.08461992335993615, 'subsample': 0.5263997334750554, 'colsample_bytree': 0.5937408038238711, 'max_depth': 3, 'min_child_weight': 83, 'reg_lambda': 0.09523416837750018, 'reg_alpha': 0.00032951597923530185, 'lambda_l1': 9.840417124224501e-05, 'lambda_l2': 0.318578091681916, 'num_leaves': 42}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:35:20,210] Trial 30 finished with value: 0.8005036526022827 and parameters: {'n_estimators': 3887, 'learning_rate': 0.18086694205426726, 'subsample': 0.5765833176920467, 'colsample_bytree': 0.10168882629527237, 'max_depth': 20, 'min_child_weight': 96, 'reg_lambda': 1.2002423884070037e-05, 'reg_alpha': 0.0001431225837802484, 'lambda_l1': 1.8457780274528117e-06, 'lambda_l2': 0.00033155506878851707, 'num_leaves': 114}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:35:40,701] Trial 31 finished with value: 0.812104838888606 and parameters: {'n_estimators': 8493, 'learning_rate': 0.070771624211825, 'subsample': 0.3952636015133851, 'colsample_bytree': 0.8147455026850171, 'max_depth': 20, 'min_child_weight': 2, 'reg_lambda': 7.387709029183457e-05, 'reg_alpha': 2.3568182910361884e-05, 'lambda_l1': 6.465953273324044e-08, 'lambda_l2': 0.20575257459672477, 'num_leaves': 63}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:35:46,815] Trial 32 finished with value: 0.8104260239353449 and parameters: {'n_estimators': 2191, 'learning_rate': 0.10435132714333041, 'subsample': 0.4669132635198952, 'colsample_bytree': 0.9169763250107192, 'max_depth': 20, 'min_child_weight': 25, 'reg_lambda': 0.007018869824083626, 'reg_alpha': 1.0265279796165968e-05, 'lambda_l1': 3.1523226415786566e-06, 'lambda_l2': 0.004587597702024083, 'num_leaves': 14}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:36:03,816] Trial 33 finished with value: 0.8129558162705173 and parameters: {'n_estimators': 8608, 'learning_rate': 0.038100491380694324, 'subsample': 0.3281861673343912, 'colsample_bytree': 0.6263930509860557, 'max_depth': 20, 'min_child_weight': 50, 'reg_lambda': 0.00026076189617858623, 'reg_alpha': 6.021528424171794e-05, 'lambda_l1': 5.12364604228177e-08, 'lambda_l2': 0.03448669907739543, 'num_leaves': 80}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:36:08,156] Trial 34 finished with value: 0.8112164743426845 and parameters: {'n_estimators': 1034, 'learning_rate': 0.13373057043575357, 'subsample': 0.4407743233134116, 'colsample_bytree': 0.7942882180810087, 'max_depth': 20, 'min_child_weight': 18, 'reg_lambda': 0.7238758138383902, 'reg_alpha': 2.660261189567051e-05, 'lambda_l1': 8.018703143886408e-08, 'lambda_l2': 0.0026359148287425083, 'num_leaves': 36}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:36:15,685] Trial 35 finished with value: 0.8129879237672311 and parameters: {'n_estimators': 6923, 'learning_rate': 0.2753310669165596, 'subsample': 0.6182610038510222, 'colsample_bytree': 0.4649564647863504, 'max_depth': 9, 'min_child_weight': 16, 'reg_lambda': 3.04537953635204, 'reg_alpha': 0.00011610519017351069, 'lambda_l1': 1.2478649648784066, 'lambda_l2': 0.16814518460047562, 'num_leaves': 56}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:36:30,346] Trial 36 finished with value: 0.808521861152153 and parameters: {'n_estimators': 7325, 'learning_rate': 0.05807923665646431, 'subsample': 0.5244206518633547, 'colsample_bytree': 0.9152795692143334, 'max_depth': 5, 'min_child_weight': 42, 'reg_lambda': 0.23721269325228955, 'reg_alpha': 2.0612350936149326, 'lambda_l1': 0.006965306626003305, 'lambda_l2': 0.9252183556642755, 'num_leaves': 123}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:36:37,325] Trial 37 finished with value: 0.8088450652180583 and parameters: {'n_estimators': 6206, 'learning_rate': 0.35674059467974756, 'subsample': 0.8190529711918759, 'colsample_bytree': 0.5557944201146492, 'max_depth': 11, 'min_child_weight': 65, 'reg_lambda': 0.02800474086044495, 'reg_alpha': 0.00025795569540338937, 'lambda_l1': 3.1170134970588417, 'lambda_l2': 0.01541340561434232, 'num_leaves': 98}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:36:44,272] Trial 38 finished with value: 0.7675660639644711 and parameters: {'n_estimators': 4914, 'learning_rate': 0.1831623571188541, 'subsample': 0.37143695053548553, 'colsample_bytree': 0.7310149529238021, 'max_depth': 20, 'min_child_weight': 175, 'reg_lambda': 0.0004721922194009217, 'reg_alpha': 0.0005416939981667677, 'lambda_l1': 0.2163458830928271, 'lambda_l2': 0.00010731503292818313, 'num_leaves': 2}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:37:08,145] Trial 39 finished with value: 0.8163088615648153 and parameters: {'n_estimators': 7531, 'learning_rate': 0.0017417746417197864, 'subsample': 0.26940014693105807, 'colsample_bytree': 0.5115258120540724, 'max_depth': 15, 'min_child_weight': 18, 'reg_lambda': 0.004377947743980155, 'reg_alpha': 4.985644194583059e-05, 'lambda_l1': 2.6922098863777317e-06, 'lambda_l2': 7.0064605348747016, 'num_leaves': 189}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:37:19,840] Trial 40 finished with value: 0.7645365678571334 and parameters: {'n_estimators': 7474, 'learning_rate': 0.5971911606739724, 'subsample': 0.2798126208851735, 'colsample_bytree': 0.40932570314889716, 'max_depth': 15, 'min_child_weight': 228, 'reg_lambda': 0.0012085865077396628, 'reg_alpha': 0.003889149879625246, 'lambda_l1': 5.313677725778814e-06, 'lambda_l2': 6.825098992270123, 'num_leaves': 189}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:37:39,256] Trial 41 finished with value: 0.8086666130508714 and parameters: {'n_estimators': 7822, 'learning_rate': 0.03328834169674409, 'subsample': 0.20619210271169167, 'colsample_bytree': 0.5351232954176235, 'max_depth': 15, 'min_child_weight': 16, 'reg_lambda': 0.008694613680647544, 'reg_alpha': 5.546242714536297e-05, 'lambda_l1': 2.874409361888908e-08, 'lambda_l2': 0.9225768871457914, 'num_leaves': 218}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:37:55,074] Trial 42 finished with value: 0.7914205322590854 and parameters: {'n_estimators': 8424, 'learning_rate': 0.9877984049444144, 'subsample': 0.3286046054219366, 'colsample_bytree': 0.5003403523396847, 'max_depth': 15, 'min_child_weight': 33, 'reg_lambda': 0.003971404515167519, 'reg_alpha': 1.4534038011618613e-05, 'lambda_l1': 4.65684626937622e-07, 'lambda_l2': 1.93272027064376, 'num_leaves': 169}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:38:15,114] Trial 43 finished with value: 0.8069741642403239 and parameters: {'n_estimators': 8999, 'learning_rate': 0.10104162638199038, 'subsample': 0.18781451359404897, 'colsample_bytree': 0.6182456448942197, 'max_depth': 13, 'min_child_weight': 5, 'reg_lambda': 0.0016607920488157317, 'reg_alpha': 3.2093705171247925e-05, 'lambda_l1': 1.2511195817047233e-06, 'lambda_l2': 0.05738533878964757, 'num_leaves': 153}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:38:30,392] Trial 44 finished with value: 0.8086480811919886 and parameters: {'n_estimators': 6514, 'learning_rate': 0.0012861229438068666, 'subsample': 0.1310909108283742, 'colsample_bytree': 0.7807204762881181, 'max_depth': 15, 'min_child_weight': 72, 'reg_lambda': 0.020813124039356826, 'reg_alpha': 0.0001057983220914018, 'lambda_l1': 1.2369838089144845e-07, 'lambda_l2': 0.015658072984885918, 'num_leaves': 194}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:38:37,788] Trial 45 finished with value: 0.7607629051070507 and parameters: {'n_estimators': 4377, 'learning_rate': 0.1325217836331072, 'subsample': 0.2737711889379887, 'colsample_bytree': 0.3921019048690555, 'max_depth': 7, 'min_child_weight': 277, 'reg_lambda': 0.19702453984114135, 'reg_alpha': 1.8205525024712287e-05, 'lambda_l1': 1.694600505399739e-07, 'lambda_l2': 3.272256890832875, 'num_leaves': 209}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:38:57,761] Trial 46 finished with value: 0.8055157813541587 and parameters: {'n_estimators': 9598, 'learning_rate': 0.06677074377119946, 'subsample': 0.6509268341224926, 'colsample_bytree': 0.25491170240931443, 'max_depth': 17, 'min_child_weight': 26, 'reg_lambda': 0.004045559153842427, 'reg_alpha': 4.71032374979034e-05, 'lambda_l1': 1.0742943436095273e-05, 'lambda_l2': 0.0009294754361874864, 'num_leaves': 171}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:39:05,983] Trial 47 finished with value: 0.7898214886532424 and parameters: {'n_estimators': 5841, 'learning_rate': 0.20666625850789516, 'subsample': 0.71099269033392, 'colsample_bytree': 0.8542060080239813, 'max_depth': 1, 'min_child_weight': 12, 'reg_lambda': 3.3560061217429106e-05, 'reg_alpha': 0.0010700870832004812, 'lambda_l1': 2.459030441050431e-08, 'lambda_l2': 0.11577153486736788, 'num_leaves': 235}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:39:21,521] Trial 48 finished with value: 0.8118081597174118 and parameters: {'n_estimators': 7898, 'learning_rate': 0.05684357027876976, 'subsample': 0.4568010120540985, 'colsample_bytree': 0.7066667039615487, 'max_depth': 11, 'min_child_weight': 50, 'reg_lambda': 0.05551376103953134, 'reg_alpha': 0.00835971381141017, 'lambda_l1': 6.00179655601068e-05, 'lambda_l2': 0.48499172587512795, 'num_leaves': 182}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:39:25,925] Trial 49 finished with value: 0.8124302257409959 and parameters: {'n_estimators': 3120, 'learning_rate': 0.48544596806196305, 'subsample': 0.2394219994156705, 'colsample_bytree': 0.48765167448127245, 'max_depth': 20, 'min_child_weight': 2, 'reg_lambda': 0.0001107251312823304, 'reg_alpha': 0.000427792976533019, 'lambda_l1': 3.8105432644227957, 'lambda_l2': 7.486680013805785e-06, 'num_leaves': 128}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:39:38,545] Trial 50 finished with value: 0.8057157772599097 and parameters: {'n_estimators': 6780, 'learning_rate': 0.1527117680529473, 'subsample': 0.9761219588395188, 'colsample_bytree': 0.5810542464337091, 'max_depth': 3, 'min_child_weight': 28, 'reg_lambda': 0.000727362107424223, 'reg_alpha': 0.0001988874725016893, 'lambda_l1': 1.876386563825189e-07, 'lambda_l2': 0.0031171942984734202, 'num_leaves': 148}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:39:43,783] Trial 51 finished with value: 0.814471998720574 and parameters: {'n_estimators': 1340, 'learning_rate': 0.004727751180005607, 'subsample': 0.6111753388653721, 'colsample_bytree': 0.41571839678462413, 'max_depth': 20, 'min_child_weight': 42, 'reg_lambda': 3.556368504109198, 'reg_alpha': 8.958300615118907e-05, 'lambda_l1': 0.0007878573071717979, 'lambda_l2': 0.0003204207853521309, 'num_leaves': 99}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:39:49,540] Trial 52 finished with value: 0.8128477734892879 and parameters: {'n_estimators': 2056, 'learning_rate': 0.03304840669764196, 'subsample': 0.6032821010666047, 'colsample_bytree': 0.34171454336530505, 'max_depth': 20, 'min_child_weight': 43, 'reg_lambda': 3.6330415878213826, 'reg_alpha': 8.60634529424332e-05, 'lambda_l1': 0.0007535252011424919, 'lambda_l2': 5.6521377776479414e-05, 'num_leaves': 72}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:39:54,003] Trial 53 finished with value: 0.8119011184240168 and parameters: {'n_estimators': 1530, 'learning_rate': 0.10691532003964697, 'subsample': 0.6668335201720138, 'colsample_bytree': 0.40965194118422615, 'max_depth': 20, 'min_child_weight': 57, 'reg_lambda': 8.549240500457799, 'reg_alpha': 0.2516462464598454, 'lambda_l1': 0.00041751898447870073, 'lambda_l2': 0.00018063109432253714, 'num_leaves': 89}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:40:00,502] Trial 54 finished with value: 0.8040971393856555 and parameters: {'n_estimators': 2426, 'learning_rate': 0.00235330999339928, 'subsample': 0.49006800745928014, 'colsample_bytree': 0.2652854720599656, 'max_depth': 20, 'min_child_weight': 75, 'reg_lambda': 0.836807008276053, 'reg_alpha': 1.0357369036178909e-05, 'lambda_l1': 0.4232503990646505, 'lambda_l2': 0.0007431283180232073, 'num_leaves': 107}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:40:04,800] Trial 55 finished with value: 0.8024285914556802 and parameters: {'n_estimators': 1429, 'learning_rate': 0.7934625376224149, 'subsample': 0.41360043365595145, 'colsample_bytree': 0.5141325279938568, 'max_depth': 13, 'min_child_weight': 40, 'reg_lambda': 1.9144473506580664, 'reg_alpha': 3.753657731182469e-05, 'lambda_l1': 0.07192051531809408, 'lambda_l2': 0.0016495902731389312, 'num_leaves': 134}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:40:19,410] Trial 56 finished with value: 0.800333807182365 and parameters: {'n_estimators': 7151, 'learning_rate': 0.4250686696533421, 'subsample': 0.71285523135679, 'colsample_bytree': 0.45715610077939184, 'max_depth': 20, 'min_child_weight': 13, 'reg_lambda': 5.947091013422814, 'reg_alpha': 8.908586560909748e-05, 'lambda_l1': 0.001999059138684774, 'lambda_l2': 0.0002023356159298938, 'num_leaves': 86}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:40:31,455] Trial 57 finished with value: 0.8097319454840333 and parameters: {'n_estimators': 4995, 'learning_rate': 0.041343560239653306, 'subsample': 0.3431290916436545, 'colsample_bytree': 0.9593807461782413, 'max_depth': 15, 'min_child_weight': 27, 'reg_lambda': 2.178623315027294, 'reg_alpha': 2.2608412043526077e-05, 'lambda_l1': 2.236485445125085e-05, 'lambda_l2': 0.0004748164658989773, 'num_leaves': 163}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:40:46,431] Trial 58 finished with value: 0.8066625009139624 and parameters: {'n_estimators': 8950, 'learning_rate': 0.09560501490187542, 'subsample': 0.5874032189927004, 'colsample_bytree': 0.8320642356613608, 'max_depth': 9, 'min_child_weight': 91, 'reg_lambda': 0.01348605483062424, 'reg_alpha': 0.0007447360954677022, 'lambda_l1': 1.1321832996992034e-08, 'lambda_l2': 0.007733825329059684, 'num_leaves': 69}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:40:56,843] Trial 59 finished with value: 0.7927703149688686 and parameters: {'n_estimators': 6306, 'learning_rate': 0.24958838596456012, 'subsample': 0.8061810874089039, 'colsample_bytree': 0.6452352939167658, 'max_depth': 20, 'min_child_weight': 139, 'reg_lambda': 0.43112908849781273, 'reg_alpha': 0.0002340625486696519, 'lambda_l1': 0.603477451474229, 'lambda_l2': 2.844149224817841e-06, 'num_leaves': 105}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:41:00,774] Trial 60 finished with value: 0.8091645210668539 and parameters: {'n_estimators': 1069, 'learning_rate': 0.03492976264242344, 'subsample': 0.5163199234117484, 'colsample_bytree': 0.8951654843067094, 'max_depth': 7, 'min_child_weight': 64, 'reg_lambda': 0.15917447081652528, 'reg_alpha': 0.015296422628147729, 'lambda_l1': 4.020860024785483, 'lambda_l2': 4.5374158815468503e-05, 'num_leaves': 118}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:41:07,239] Trial 61 finished with value: 0.814245006592104 and parameters: {'n_estimators': 2572, 'learning_rate': 0.027254660770400833, 'subsample': 0.6537360077049427, 'colsample_bytree': 0.3925307143980171, 'max_depth': 20, 'min_child_weight': 37, 'reg_lambda': 7.86601731330808, 'reg_alpha': 0.00012764881515568027, 'lambda_l1': 2.8119868169113205, 'lambda_l2': 1.5928565757910258e-05, 'num_leaves': 95}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:41:11,553] Trial 62 finished with value: 0.8042767847039294 and parameters: {'n_estimators': 1648, 'learning_rate': 0.07103831154025837, 'subsample': 0.6165618407438553, 'colsample_bytree': 0.433270829130547, 'max_depth': 20, 'min_child_weight': 111, 'reg_lambda': 4.419736728576419, 'reg_alpha': 0.00016088619404084609, 'lambda_l1': 0.7642397180125553, 'lambda_l2': 6.093143129818362e-08, 'num_leaves': 137}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:41:20,566] Trial 63 finished with value: 0.8087073140449286 and parameters: {'n_estimators': 1781, 'learning_rate': 0.005114290181185199, 'subsample': 0.6285294074699044, 'colsample_bytree': 0.3115511693241104, 'max_depth': 20, 'min_child_weight': 8, 'reg_lambda': 1.00840834889705, 'reg_alpha': 0.0016498738843314206, 'lambda_l1': 0.19849389650263516, 'lambda_l2': 0.0004107876543716308, 'num_leaves': 80}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:41:23,863] Trial 64 finished with value: 0.8095090382605937 and parameters: {'n_estimators': 1237, 'learning_rate': 0.11870317377833436, 'subsample': 0.6977876112408099, 'colsample_bytree': 0.5854073591273938, 'max_depth': 5, 'min_child_weight': 22, 'reg_lambda': 9.214206721043977, 'reg_alpha': 4.885309658030241e-05, 'lambda_l1': 8.915363763658464, 'lambda_l2': 0.0016692364986879854, 'num_leaves': 50}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:41:33,094] Trial 65 finished with value: 0.8147148854529076 and parameters: {'n_estimators': 5794, 'learning_rate': 0.08572633909772591, 'subsample': 0.5527638844056689, 'colsample_bytree': 0.44096769269402136, 'max_depth': 20, 'min_child_weight': 54, 'reg_lambda': 2.304988795949825, 'reg_alpha': 0.0003671821729528617, 'lambda_l1': 1.7811918145500603, 'lambda_l2': 4.5024305022099856e-07, 'num_leaves': 62}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:41:44,428] Trial 66 finished with value: 0.8107954767895766 and parameters: {'n_estimators': 5747, 'learning_rate': 0.15853571611712927, 'subsample': 0.5470725026859437, 'colsample_bytree': 0.4821098258573442, 'max_depth': 17, 'min_child_weight': 53, 'reg_lambda': 0.5760123731510869, 'reg_alpha': 0.00042514858050161133, 'lambda_l1': 0.03995032497905403, 'lambda_l2': 7.547291931919754e-08, 'num_leaves': 62}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:41:56,250] Trial 67 finished with value: 0.8070726776047301 and parameters: {'n_estimators': 5401, 'learning_rate': 0.0791825302222929, 'subsample': 0.550190071582034, 'colsample_bytree': 0.7629107105568145, 'max_depth': 20, 'min_child_weight': 31, 'reg_lambda': 1.7036611685512002, 'reg_alpha': 1.7316737861514613e-05, 'lambda_l1': 8.139134646803508e-06, 'lambda_l2': 2.725772851490923e-07, 'num_leaves': 44}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:42:03,638] Trial 68 finished with value: 0.7884703489396443 and parameters: {'n_estimators': 4607, 'learning_rate': 0.19622688383777553, 'subsample': 0.7287514344902557, 'colsample_bytree': 0.37201928152754804, 'max_depth': 1, 'min_child_weight': 45, 'reg_lambda': 2.403164865137169, 'reg_alpha': 7.355087696781832e-05, 'lambda_l1': 0.011365477810717766, 'lambda_l2': 1.9653260897592904e-08, 'num_leaves': 179}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:42:12,293] Trial 69 finished with value: 0.8113269486968566 and parameters: {'n_estimators': 5265, 'learning_rate': 0.13289439627243868, 'subsample': 0.36964443918864487, 'colsample_bytree': 0.6924580170597829, 'max_depth': 20, 'min_child_weight': 83, 'reg_lambda': 0.002056384103134022, 'reg_alpha': 0.00033206459203381956, 'lambda_l1': 1.718530407687209, 'lambda_l2': 9.72839533277382e-07, 'num_leaves': 27}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:42:30,784] Trial 70 finished with value: 0.8076072011311988 and parameters: {'n_estimators': 9994, 'learning_rate': 0.05733601439697081, 'subsample': 0.43561052979975545, 'colsample_bytree': 0.5261382215235214, 'max_depth': 3, 'min_child_weight': 10, 'reg_lambda': 0.05038546360330446, 'reg_alpha': 3.639205040025083e-05, 'lambda_l1': 2.8425265110601982e-08, 'lambda_l2': 5.560633676303662e-07, 'num_leaves': 52}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:42:37,131] Trial 71 finished with value: 0.8126817151874514 and parameters: {'n_estimators': 1906, 'learning_rate': 0.0030540079717248326, 'subsample': 0.6730211178539403, 'colsample_bytree': 0.4354805729922021, 'max_depth': 20, 'min_child_weight': 34, 'reg_lambda': 5.481048102192091, 'reg_alpha': 0.00016758868030712398, 'lambda_l1': 1.7532773997383786, 'lambda_l2': 0.00010635807832424457, 'num_leaves': 78}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:42:42,627] Trial 72 finished with value: 0.8075171917485952 and parameters: {'n_estimators': 4112, 'learning_rate': 0.0887936731635654, 'subsample': 0.6356576913991134, 'colsample_bytree': 0.4602943204205971, 'max_depth': 20, 'min_child_weight': 64, 'reg_lambda': 0.005935057816575745, 'reg_alpha': 0.0001234829564348522, 'lambda_l1': 8.461837394800467, 'lambda_l2': 0.004302532460497497, 'num_leaves': 65}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:42:47,269] Trial 73 finished with value: 0.7771185902689973 and parameters: {'n_estimators': 2349, 'learning_rate': 0.027805953891451827, 'subsample': 0.49794227063094404, 'colsample_bytree': 0.8807037465859939, 'max_depth': 20, 'min_child_weight': 214, 'reg_lambda': 1.0818281732610562, 'reg_alpha': 0.0006055982456090534, 'lambda_l1': 0.12338103111345017, 'lambda_l2': 0.017992929969467466, 'num_leaves': 92}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:43:01,505] Trial 74 finished with value: 0.8098517418647129 and parameters: {'n_estimators': 5910, 'learning_rate': 0.05467539400157856, 'subsample': 0.5945454165206756, 'colsample_bytree': 0.558809712517328, 'max_depth': 20, 'min_child_weight': 18, 'reg_lambda': 4.115461959016488, 'reg_alpha': 0.0010523689971565129, 'lambda_l1': 0.3529367028095029, 'lambda_l2': 1.5891499653665716e-07, 'num_leaves': 105}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:43:09,839] Trial 75 finished with value: 0.8102183454871914 and parameters: {'n_estimators': 8208, 'learning_rate': 0.5391107176262427, 'subsample': 0.5680483819139049, 'colsample_bytree': 0.7311087417843648, 'max_depth': 11, 'min_child_weight': 57, 'reg_lambda': 2.957611439938039, 'reg_alpha': 8.307314511668979, 'lambda_l1': 0.9446449712925374, 'lambda_l2': 0.0002604598613330049, 'num_leaves': 83}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:43:14,149] Trial 76 finished with value: 0.8140903337492078 and parameters: {'n_estimators': 1309, 'learning_rate': 0.11293639748719138, 'subsample': 0.7511672847778694, 'colsample_bytree': 0.428575316123727, 'max_depth': 15, 'min_child_weight': 41, 'reg_lambda': 9.763942772133191, 'reg_alpha': 0.00022951383299715195, 'lambda_l1': 8.887360363203229e-07, 'lambda_l2': 0.000704273854900175, 'num_leaves': 124}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:43:33,274] Trial 77 finished with value: 0.8091240001554357 and parameters: {'n_estimators': 7648, 'learning_rate': 0.01912956346231019, 'subsample': 0.6791300991308349, 'colsample_bytree': 0.3658611348926238, 'max_depth': 20, 'min_child_weight': 20, 'reg_lambda': 0.3305470590559792, 'reg_alpha': 6.758274349509851e-05, 'lambda_l1': 3.2612688967273263e-06, 'lambda_l2': 0.04354634888706341, 'num_leaves': 58}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:43:46,618] Trial 78 finished with value: 0.8128409081652508 and parameters: {'n_estimators': 7115, 'learning_rate': 0.08718010036421885, 'subsample': 0.24273114199784482, 'colsample_bytree': 0.4845426308839447, 'max_depth': 9, 'min_child_weight': 73, 'reg_lambda': 2.6363126974545402e-05, 'reg_alpha': 0.00034159648363843025, 'lambda_l1': 3.2361047359351905e-07, 'lambda_l2': 0.08105067748280316, 'num_leaves': 201}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:44:01,977] Trial 79 finished with value: 0.8088789523522664 and parameters: {'n_estimators': 6502, 'learning_rate': 0.1704662816198342, 'subsample': 0.3906143752823612, 'colsample_bytree': 0.5067549410433124, 'max_depth': 20, 'min_child_weight': 4, 'reg_lambda': 1.5281921898151363, 'reg_alpha': 2.4399697926175455e-05, 'lambda_l1': 4.991934256366806e-08, 'lambda_l2': 7.119366324623107e-06, 'num_leaves': 162}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:44:09,581] Trial 80 finished with value: 0.805894858166609 and parameters: {'n_estimators': 3610, 'learning_rate': 0.7042401726044936, 'subsample': 0.3063447395222473, 'colsample_bytree': 0.313380071779377, 'max_depth': 13, 'min_child_weight': 48, 'reg_lambda': 0.0027602671808749737, 'reg_alpha': 0.002342402091384497, 'lambda_l1': 0.0001555156850903552, 'lambda_l2': 4.3143041431822394e-08, 'num_leaves': 99}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:44:16,688] Trial 81 finished with value: 0.8164699802553372 and parameters: {'n_estimators': 2973, 'learning_rate': 0.030525890552873178, 'subsample': 0.6312540387742991, 'colsample_bytree': 0.3929480261359367, 'max_depth': 20, 'min_child_weight': 37, 'reg_lambda': 6.203137737471955, 'reg_alpha': 0.0001254219357620913, 'lambda_l1': 2.6829838890524393, 'lambda_l2': 3.0306368690765568e-05, 'num_leaves': 97}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:44:29,481] Trial 82 finished with value: 0.8126414901251555 and parameters: {'n_estimators': 5547, 'learning_rate': 0.051616709200755256, 'subsample': 0.6406700751627614, 'colsample_bytree': 0.40674409325694827, 'max_depth': 20, 'min_child_weight': 28, 'reg_lambda': 6.099505792462538, 'reg_alpha': 9.548329443642871e-05, 'lambda_l1': 0.6004987528384024, 'lambda_l2': 1.5538553427098518e-06, 'num_leaves': 150}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:44:35,578] Trial 83 finished with value: 0.8128386166977576 and parameters: {'n_estimators': 3001, 'learning_rate': 0.027259629598477726, 'subsample': 0.14604715349983555, 'colsample_bytree': 0.4701792295953878, 'max_depth': 20, 'min_child_weight': 37, 'reg_lambda': 2.738255518225781, 'reg_alpha': 4.639695795864659e-05, 'lambda_l1': 5.697505535101447, 'lambda_l2': 2.9651923033559755e-07, 'num_leaves': 117}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:44:40,266] Trial 84 finished with value: 0.8083858132633202 and parameters: {'n_estimators': 1748, 'learning_rate': 0.07246189620546602, 'subsample': 0.5473934488128482, 'colsample_bytree': 0.22410883057659242, 'max_depth': 5, 'min_child_weight': 10, 'reg_lambda': 4.46667064250615, 'reg_alpha': 0.00014925006901559497, 'lambda_l1': 1.5335790928204887, 'lambda_l2': 8.914292515689126e-05, 'num_leaves': 74}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:44:45,658] Trial 85 finished with value: 0.8167361924612091 and parameters: {'n_estimators': 2658, 'learning_rate': 0.1274135326659459, 'subsample': 0.6047988457788968, 'colsample_bytree': 0.3523192390489338, 'max_depth': 20, 'min_child_weight': 21, 'reg_lambda': 6.60212741922853, 'reg_alpha': 0.05689519653364717, 'lambda_l1': 2.461286507980405, 'lambda_l2': 9.300825948403228, 'num_leaves': 211}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:44:51,489] Trial 86 finished with value: 0.8147152019123244 and parameters: {'n_estimators': 3389, 'learning_rate': 0.1431831222324738, 'subsample': 0.6002947125755326, 'colsample_bytree': 0.3224192438474061, 'max_depth': 20, 'min_child_weight': 20, 'reg_lambda': 6.382054169594792, 'reg_alpha': 0.12489519027328316, 'lambda_l1': 2.284212380075579, 'lambda_l2': 8.315047461071664, 'num_leaves': 228}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:44:56,503] Trial 87 finished with value: 0.8084321715453251 and parameters: {'n_estimators': 2611, 'learning_rate': 0.1438657933830768, 'subsample': 0.5845446726089282, 'colsample_bytree': 0.1973218837320997, 'max_depth': 7, 'min_child_weight': 19, 'reg_lambda': 0.012434060114641618, 'reg_alpha': 0.057990369868849194, 'lambda_l1': 2.657372531601611, 'lambda_l2': 8.543525579732128, 'num_leaves': 237}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:45:01,368] Trial 88 finished with value: 0.8145553064437376 and parameters: {'n_estimators': 2764, 'learning_rate': 0.12267636198206923, 'subsample': 0.5239958516444732, 'colsample_bytree': 0.3414721604070451, 'max_depth': 15, 'min_child_weight': 24, 'reg_lambda': 0.00020692517292890788, 'reg_alpha': 0.13096184575038403, 'lambda_l1': 5.23038857859902, 'lambda_l2': 2.973602550488056, 'num_leaves': 227}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:45:06,469] Trial 89 finished with value: 0.8134845188743313 and parameters: {'n_estimators': 3229, 'learning_rate': 0.24366639681975139, 'subsample': 0.6869661429467979, 'colsample_bytree': 0.28870289453444575, 'max_depth': 20, 'min_child_weight': 3, 'reg_lambda': 6.399829647556372, 'reg_alpha': 0.560204333568364, 'lambda_l1': 2.4210802579852784, 'lambda_l2': 4.3050842207077045, 'num_leaves': 218}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:45:12,237] Trial 90 finished with value: 0.8102135402861389 and parameters: {'n_estimators': 4058, 'learning_rate': 0.22102793366201512, 'subsample': 0.4637593600998119, 'colsample_bytree': 0.3720669324459185, 'max_depth': 17, 'min_child_weight': 1, 'reg_lambda': 0.0007826648936465554, 'reg_alpha': 0.032467160255199384, 'lambda_l1': 1.1501764175421934, 'lambda_l2': 1.5744627526487267, 'num_leaves': 209}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:45:16,844] Trial 91 finished with value: 0.8154222859389202 and parameters: {'n_estimators': 2733, 'learning_rate': 0.126990078294394, 'subsample': 0.6005909758035739, 'colsample_bytree': 0.35343064606424546, 'max_depth': 15, 'min_child_weight': 24, 'reg_lambda': 0.00018584072291254067, 'reg_alpha': 0.17818158570212825, 'lambda_l1': 6.016261081896688, 'lambda_l2': 2.8332906190447353, 'num_leaves': 230}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:45:22,108] Trial 92 finished with value: 0.8171685426990288 and parameters: {'n_estimators': 3441, 'learning_rate': 0.08247883373364198, 'subsample': 0.6021213659225398, 'colsample_bytree': 0.2981345925917339, 'max_depth': 15, 'min_child_weight': 12, 'reg_lambda': 6.919667835571987e-05, 'reg_alpha': 0.14842069369325978, 'lambda_l1': 6.143112788145868, 'lambda_l2': 9.443847781699183, 'num_leaves': 244}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:45:27,370] Trial 93 finished with value: 0.8165173705772253 and parameters: {'n_estimators': 3611, 'learning_rate': 0.1063031372979416, 'subsample': 0.594811181353951, 'colsample_bytree': 0.3101422408877036, 'max_depth': 15, 'min_child_weight': 14, 'reg_lambda': 7.171448354135645e-05, 'reg_alpha': 0.4541579948998337, 'lambda_l1': 5.762728441541663, 'lambda_l2': 0.44405774463698877, 'num_leaves': 256}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:45:32,770] Trial 94 finished with value: 0.8127611821108627 and parameters: {'n_estimators': 3873, 'learning_rate': 0.10820041376056583, 'subsample': 0.5745283123174824, 'colsample_bytree': 0.29116920439632626, 'max_depth': 15, 'min_child_weight': 13, 'reg_lambda': 5.654661399345434e-05, 'reg_alpha': 0.4581649806141746, 'lambda_l1': 5.68661934381732, 'lambda_l2': 0.5000670306971063, 'num_leaves': 254}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:45:37,818] Trial 95 finished with value: 0.8095118073020269 and parameters: {'n_estimators': 3455, 'learning_rate': 0.18539433222170604, 'subsample': 0.6550864506353443, 'colsample_bytree': 0.24727566946392976, 'max_depth': 15, 'min_child_weight': 31, 'reg_lambda': 1.0386867378943237e-05, 'reg_alpha': 0.7956423275204269, 'lambda_l1': 9.743474522247503, 'lambda_l2': 0.852027421326657, 'num_leaves': 239}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:45:43,088] Trial 96 finished with value: 0.8158365031399905 and parameters: {'n_estimators': 2813, 'learning_rate': 0.04868074354480587, 'subsample': 0.7320293474448085, 'colsample_bytree': 0.35004241568095623, 'max_depth': 15, 'min_child_weight': 11, 'reg_lambda': 8.816775217066902e-05, 'reg_alpha': 0.14991310374812272, 'lambda_l1': 5.032302482653767, 'lambda_l2': 2.9007072567401693, 'num_leaves': 246}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:45:48,713] Trial 97 finished with value: 0.8093051213559079 and parameters: {'n_estimators': 2775, 'learning_rate': 0.047143067137749295, 'subsample': 0.7327615945848862, 'colsample_bytree': 0.17407045765396842, 'max_depth': 15, 'min_child_weight': 11, 'reg_lambda': 7.795143312904663e-05, 'reg_alpha': 0.18095051992396, 'lambda_l1': 3.3705412497179057, 'lambda_l2': 2.58327951610417, 'num_leaves': 249}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:45:53,525] Trial 98 finished with value: 0.8142671633462605 and parameters: {'n_estimators': 3112, 'learning_rate': 0.3190077442074193, 'subsample': 0.7825973488029324, 'colsample_bytree': 0.3518164574288511, 'max_depth': 15, 'min_child_weight': 25, 'reg_lambda': 0.00014871430477664347, 'reg_alpha': 0.3132940670053572, 'lambda_l1': 5.477631964316922, 'lambda_l2': 5.146269494826726, 'num_leaves': 243}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:45:58,167] Trial 99 finished with value: 0.7919806905650217 and parameters: {'n_estimators': 2214, 'learning_rate': 0.0480246788866554, 'subsample': 0.6217281493713066, 'colsample_bytree': 0.26981625270821696, 'max_depth': 15, 'min_child_weight': 161, 'reg_lambda': 1.8140115785365453e-05, 'reg_alpha': 0.09625115668369945, 'lambda_l1': 0.5767188760042118, 'lambda_l2': 1.622521458248694, 'num_leaves': 224}. Best is trial 14 with value: 0.8183553899612376.
# ...
# [I 2022-02-19 14:47:59,771] Trial 118 finished with value: 0.8179982612874064 and parameters: {'n_estimators': 2525, 'learning_rate': 0.08425464263650055, 'subsample': 0.827263198637801, 'colsample_bytree': 0.6394406492671882, 'max_depth': 9, 'min_child_weight': 29, 'reg_lambda': 3.130227689778496e-05, 'reg_alpha': 0.366878091796017, 'lambda_l1': 0.9164450662241491, 'lambda_l2': 2.1640555419430982, 'num_leaves': 187}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:48:06,500] Trial 119 finished with value: 0.8137478383245892 and parameters: {'n_estimators': 2546, 'learning_rate': 0.08239540490282027, 'subsample': 0.6695466198910658, 'colsample_bytree': 0.6510571939209973, 'max_depth': 9, 'min_child_weight': 29, 'reg_lambda': 0.00041238158619183067, 'reg_alpha': 0.20771655918316453, 'lambda_l1': 1.0168764894552942, 'lambda_l2': 2.087989573949644, 'num_leaves': 174}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:48:12,366] Trial 120 finished with value: 0.8156267093948737 and parameters: {'n_estimators': 2633, 'learning_rate': 0.14479987663278393, 'subsample': 0.7469215857370017, 'colsample_bytree': 0.9587920707389583, 'max_depth': 9, 'min_child_weight': 60, 'reg_lambda': 1.4465243671919354e-05, 'reg_alpha': 0.3568878406647526, 'lambda_l1': 0.10215063362486435, 'lambda_l2': 1.473870227280348, 'num_leaves': 203}. Best is trial 14 with value: 0.8183553899612376.
# [I 2022-02-19 14:48:17,946] Trial 121 finished with value: 0.8187525442858844 and parameters: {'n_estimators': 1964, 'learning_rate': 0.019000163610413685, 'subsample': 0.8290862139366966, 'colsample_bytree': 0.6780340737986891, 'max_depth': 9, 'min_child_weight': 37, 'reg_lambda': 3.195961754374143e-05, 'reg_alpha': 0.28525992490436297, 'lambda_l1': 1.53990859048609, 'lambda_l2': 3.8750259446628514, 'num_leaves': 186}. Best is trial 121 with value: 0.8187525442858844.
# [I 2022-02-19 14:48:23,411] Trial 122 finished with value: 0.8190897902437937 and parameters: {'n_estimators': 2054, 'learning_rate': 0.03845606680900882, 'subsample': 0.8149592605479348, 'colsample_bytree': 0.6674956139538465, 'max_depth': 9, 'min_child_weight': 38, 'reg_lambda': 3.0038935221482155e-05, 'reg_alpha': 0.6105769877095591, 'lambda_l1': 1.6933558796498673, 'lambda_l2': 4.290210404421428, 'num_leaves': 182}. Best is trial 122 with value: 0.8190897902437937.
# [I 2022-02-19 14:48:27,900] Trial 123 finished with value: 0.8088638483138041 and parameters: {'n_estimators': 1577, 'learning_rate': 0.6280977127158132, 'subsample': 0.8161928578646821, 'colsample_bytree': 0.6718481414473074, 'max_depth': 9, 'min_child_weight': 40, 'reg_lambda': 2.6935232508829344e-05, 'reg_alpha': 0.5939313629245799, 'lambda_l1': 0.4620074722035165, 'lambda_l2': 6.642139670141597, 'num_leaves': 184}. Best is trial 122 with value: 0.8190897902437937.
# [I 2022-02-19 14:48:33,728] Trial 124 finished with value: 0.8163735672064357 and parameters: {'n_estimators': 1981, 'learning_rate': 0.014410442038074357, 'subsample': 0.8332270792152081, 'colsample_bytree': 0.6304205605392905, 'max_depth': 9, 'min_child_weight': 36, 'reg_lambda': 4.301802301577129e-05, 'reg_alpha': 0.27117952867157363, 'lambda_l1': 1.5353952443596337, 'lambda_l2': 4.098460552161486, 'num_leaves': 197}. Best is trial 122 with value: 0.8190897902437937.
# [I 2022-02-19 14:48:38,812] Trial 125 finished with value: 0.8148449123723271 and parameters: {'n_estimators': 1906, 'learning_rate': 0.07022910274344017, 'subsample': 0.8325160919008254, 'colsample_bytree': 0.6255690362459018, 'max_depth': 9, 'min_child_weight': 52, 'reg_lambda': 4.683026433232803e-05, 'reg_alpha': 0.6906314982767581, 'lambda_l1': 0.16527149979263978, 'lambda_l2': 0.34690554833772635, 'num_leaves': 199}. Best is trial 122 with value: 0.8190897902437937.
# [I 2022-02-19 14:48:44,418] Trial 126 finished with value: 0.8122277014582938 and parameters: {'n_estimators': 2124, 'learning_rate': 0.12464566156725113, 'subsample': 0.8015643675392076, 'colsample_bytree': 0.7090058142988225, 'max_depth': 9, 'min_child_weight': 32, 'reg_lambda': 1.314281808243791e-05, 'reg_alpha': 0.2544855519973462, 'lambda_l1': 0.3231773444036914, 'lambda_l2': 1.1499038670970385, 'num_leaves': 186}. Best is trial 122 with value: 0.8190897902437937.
# [I 2022-02-19 14:48:48,998] Trial 127 finished with value: 0.8082625106421911 and parameters: {'n_estimators': 1833, 'learning_rate': 0.09099803237634685, 'subsample': 0.9363765687916292, 'colsample_bytree': 0.6339535455491603, 'max_depth': 9, 'min_child_weight': 69, 'reg_lambda': 5.909436781005772e-05, 'reg_alpha': 0.43943280648888344, 'lambda_l1': 1.6187876875457903, 'lambda_l2': 4.539318507585686, 'num_leaves': 176}. Best is trial 122 with value: 0.8190897902437937.
# [I 2022-02-19 14:48:53,872] Trial 128 finished with value: 0.8170344947493138 and parameters: {'n_estimators': 1665, 'learning_rate': 0.02284000137632653, 'subsample': 0.8725257558138615, 'colsample_bytree': 0.6074332714702896, 'max_depth': 9, 'min_child_weight': 45, 'reg_lambda': 3.054517608155171e-05, 'reg_alpha': 0.31876822283637896, 'lambda_l1': 0.9049067138064179, 'lambda_l2': 2.056604034536775, 'num_leaves': 165}. Best is trial 122 with value: 0.8190897902437937.
# [I 2022-02-19 14:48:59,719] Trial 129 finished with value: 0.8104647513454118 and parameters: {'n_estimators': 2373, 'learning_rate': 0.017207998700313, 'subsample': 0.862471426043324, 'colsample_bytree': 0.6665803644552322, 'max_depth': 9, 'min_child_weight': 59, 'reg_lambda': 2.0160860872434804e-05, 'reg_alpha': 0.3003723683024999, 'lambda_l1': 1.1101831034695184, 'lambda_l2': 2.135272887373284, 'num_leaves': 163}. Best is trial 122 with value: 0.8190897902437937.
# [I 2022-02-19 14:49:12,389] Trial 130 finished with value: 0.8135886293715204 and parameters: {'n_estimators': 6199, 'learning_rate': 0.0346922404266553, 'subsample': 0.8893545329802599, 'colsample_bytree': 0.6150628423200991, 'max_depth': 9, 'min_child_weight': 45, 'reg_lambda': 3.691266909946317e-05, 'reg_alpha': 0.3921494435913033, 'lambda_l1': 0.7945230517269921, 'lambda_l2': 0.7543095341418803, 'num_leaves': 168}. Best is trial 122 with value: 0.8190897902437937.
# [I 2022-02-19 14:49:17,003] Trial 131 finished with value: 0.8195257880025968 and parameters: {'n_estimators': 1457, 'learning_rate': 0.060248749899038986, 'subsample': 0.8234446719556949, 'colsample_bytree': 0.6790730914244811, 'max_depth': 9, 'min_child_weight': 36, 'reg_lambda': 3.296433822332695e-05, 'reg_alpha': 0.012115678373433419, 'lambda_l1': 1.879256891333268, 'lambda_l2': 3.782117965153241, 'num_leaves': 180}. Best is trial 131 with value: 0.8195257880025968.
# [I 2022-02-19 14:49:21,824] Trial 132 finished with value: 0.8196551203813198 and parameters: {'n_estimators': 1637, 'learning_rate': 0.06407429140689001, 'subsample': 0.8296540497278774, 'colsample_bytree': 0.6943662937643169, 'max_depth': 9, 'min_child_weight': 36, 'reg_lambda': 2.576263448084046e-05, 'reg_alpha': 0.0050427689510791724, 'lambda_l1': 1.912864572661557, 'lambda_l2': 3.8985419027505963, 'num_leaves': 190}. Best is trial 132 with value: 0.8196551203813198.
# [I 2022-02-19 14:49:25,740] Trial 133 finished with value: 0.816650951764131 and parameters: {'n_estimators': 1212, 'learning_rate': 0.10980875874536034, 'subsample': 0.8630390448328242, 'colsample_bytree': 0.6911210610333387, 'max_depth': 9, 'min_child_weight': 45, 'reg_lambda': 2.6293574802286247e-05, 'reg_alpha': 0.011926439757459018, 'lambda_l1': 2.6573158886595114, 'lambda_l2': 2.2273185872937815, 'num_leaves': 179}. Best is trial 132 with value: 0.8196551203813198.
# [I 2022-02-19 14:49:29,529] Trial 134 finished with value: 0.8165149875084445 and parameters: {'n_estimators': 1108, 'learning_rate': 0.11141577988831391, 'subsample': 0.8692923869397501, 'colsample_bytree': 0.6933778355403094, 'max_depth': 9, 'min_child_weight': 50, 'reg_lambda': 2.7998126255593967e-05, 'reg_alpha': 0.014966244246974488, 'lambda_l1': 1.9237738649515381, 'lambda_l2': 1.4858071520089076, 'num_leaves': 156}. Best is trial 132 with value: 0.8196551203813198.
# [I 2022-02-19 14:49:33,295] Trial 135 finished with value: 0.8162922275499802 and parameters: {'n_estimators': 1090, 'learning_rate': 0.17362253270474573, 'subsample': 0.9042726072917646, 'colsample_bytree': 0.6952273174846828, 'max_depth': 9, 'min_child_weight': 49, 'reg_lambda': 2.788537934277398e-05, 'reg_alpha': 0.005377778219097362, 'lambda_l1': 0.5230074921940949, 'lambda_l2': 1.886077298431628, 'num_leaves': 155}. Best is trial 132 with value: 0.8196551203813198.
# [I 2022-02-19 14:49:37,702] Trial 136 finished with value: 0.816524610481267 and parameters: {'n_estimators': 1463, 'learning_rate': 0.12153940092387787, 'subsample': 0.8660775357703228, 'colsample_bytree': 0.7526683435718414, 'max_depth': 9, 'min_child_weight': 45, 'reg_lambda': 1.7126674005655865e-05, 'reg_alpha': 0.013832649291121431, 'lambda_l1': 0.9841623965708316, 'lambda_l2': 3.027456874444177, 'num_leaves': 178}. Best is trial 132 with value: 0.8196551203813198.
# [I 2022-02-19 14:49:42,191] Trial 137 finished with value: 0.8150769913488501 and parameters: {'n_estimators': 1485, 'learning_rate': 0.1483656396531096, 'subsample': 0.9671726704094815, 'colsample_bytree': 0.7813145295240763, 'max_depth': 9, 'min_child_weight': 45, 'reg_lambda': 1.2983510230291227e-05, 'reg_alpha': 0.006015202303563771, 'lambda_l1': 0.3202913164657141, 'lambda_l2': 6.9997217077086455, 'num_leaves': 182}. Best is trial 132 with value: 0.8196551203813198.
# [I 2022-02-19 14:49:46,829] Trial 138 finished with value: 0.8129590429225836 and parameters: {'n_estimators': 1656, 'learning_rate': 0.07868192798091847, 'subsample': 0.8244317623338409, 'colsample_bytree': 0.7353507118548291, 'max_depth': 9, 'min_child_weight': 56, 'reg_lambda': 7.334925792760285e-05, 'reg_alpha': 0.011194654797762764, 'lambda_l1': 1.1310355073817198, 'lambda_l2': 3.308241107111534, 'num_leaves': 189}. Best is trial 132 with value: 0.8196551203813198.
# [I 2022-02-19 14:49:51,379] Trial 139 finished with value: 0.8175881027472727 and parameters: {'n_estimators': 1217, 'learning_rate': 0.1302761436419388, 'subsample': 0.8474954187798924, 'colsample_bytree': 0.7203833939072124, 'max_depth': 9, 'min_child_weight': 24, 'reg_lambda': 1.0558344883379894e-05, 'reg_alpha': 0.024719621605891993, 'lambda_l1': 0.7500031059186736, 'lambda_l2': 9.852947995081054, 'num_leaves': 170}. Best is trial 132 with value: 0.8196551203813198.
# [I 2022-02-19 14:49:55,294] Trial 140 finished with value: 0.8093730660432137 and parameters: {'n_estimators': 1323, 'learning_rate': 0.19402469407173994, 'subsample': 0.8684035841531816, 'colsample_bytree': 0.7213167887937018, 'max_depth': 9, 'min_child_weight': 78, 'reg_lambda': 1.0460835381187436e-05, 'reg_alpha': 0.02351670806282734, 'lambda_l1': 0.7291990969782538, 'lambda_l2': 7.513660491202013, 'num_leaves': 172}. Best is trial 132 with value: 0.8196551203813198.
# [I 2022-02-19 14:49:59,551] Trial 141 finished with value: 0.8195420916311067 and parameters: {'n_estimators': 1223, 'learning_rate': 0.06322469012161872, 'subsample': 0.8489690206998828, 'colsample_bytree': 0.7525492903503226, 'max_depth': 9, 'min_child_weight': 25, 'reg_lambda': 1.726082141868489e-05, 'reg_alpha': 0.010873629658252811, 'lambda_l1': 3.2723060488284017, 'lambda_l2': 9.559568695266584, 'num_leaves': 178}. Best is trial 132 with value: 0.8196551203813198.
# [I 2022-02-19 14:50:03,756] Trial 142 finished with value: 0.8198282573242881 and parameters: {'n_estimators': 1211, 'learning_rate': 0.0655617061483102, 'subsample': 0.8424673374069434, 'colsample_bytree': 0.7456098558853268, 'max_depth': 9, 'min_child_weight': 28, 'reg_lambda': 1.748029886598557e-05, 'reg_alpha': 0.011816434352783945, 'lambda_l1': 3.342275961260333, 'lambda_l2': 9.28445946270099, 'num_leaves': 167}. Best is trial 142 with value: 0.8198282573242881.
# [I 2022-02-19 14:50:08,238] Trial 143 finished with value: 0.8169476767606442 and parameters: {'n_estimators': 1188, 'learning_rate': 0.05830627115036317, 'subsample': 0.8452401139106049, 'colsample_bytree': 0.6561718113124466, 'max_depth': 9, 'min_child_weight': 25, 'reg_lambda': 1.8483054519712345e-05, 'reg_alpha': 0.019881588903439204, 'lambda_l1': 3.5146823596290586, 'lambda_l2': 9.692858035471222, 'num_leaves': 166}. Best is trial 142 with value: 0.8198282573242881.
# [I 2022-02-19 14:50:12,878] Trial 144 finished with value: 0.816959072041439 and parameters: {'n_estimators': 1605, 'learning_rate': 0.05808415827454239, 'subsample': 0.841174879338097, 'colsample_bytree': 0.7465930704316103, 'max_depth': 9, 'min_child_weight': 25, 'reg_lambda': 1.830426245236191e-05, 'reg_alpha': 0.02264209985889142, 'lambda_l1': 3.8695840210842287, 'lambda_l2': 9.161744844073784, 'num_leaves': 161}. Best is trial 142 with value: 0.8198282573242881.
# [I 2022-02-19 14:50:17,510] Trial 145 finished with value: 0.8183976400417017 and parameters: {'n_estimators': 1654, 'learning_rate': 0.06386454200947107, 'subsample': 0.8499893789957558, 'colsample_bytree': 0.6753962359521429, 'max_depth': 9, 'min_child_weight': 25, 'reg_lambda': 1.8395047352257148e-05, 'reg_alpha': 0.0207500311890244, 'lambda_l1': 3.271049861721049, 'lambda_l2': 9.91128845980886, 'num_leaves': 145}. Best is trial 142 with value: 0.8198282573242881.
# [I 2022-02-19 14:50:22,014] Trial 146 finished with value: 0.8185829494822622 and parameters: {'n_estimators': 1664, 'learning_rate': 0.05962762772705553, 'subsample': 0.8411361828530795, 'colsample_bytree': 0.6531244789642409, 'max_depth': 9, 'min_child_weight': 33, 'reg_lambda': 1.7325228770926987e-05, 'reg_alpha': 0.018632851941522085, 'lambda_l1': 3.7526101025639598, 'lambda_l2': 9.296807834757178, 'num_leaves': 144}. Best is trial 142 with value: 0.8198282573242881.
# [I 2022-02-19 14:50:27,127] Trial 147 finished with value: 0.8167832588511217 and parameters: {'n_estimators': 1629, 'learning_rate': 0.05454930974580174, 'subsample': 0.925116052849603, 'colsample_bytree': 0.7441400288475608, 'max_depth': 9, 'min_child_weight': 30, 'reg_lambda': 1.4740540477458816e-05, 'reg_alpha': 0.008738637598511694, 'lambda_l1': 0.004297741679204331, 'lambda_l2': 4.3237105265567, 'num_leaves': 142}. Best is trial 142 with value: 0.8198282573242881.
# [I 2022-02-19 14:50:31,653] Trial 148 finished with value: 0.8173544506351611 and parameters: {'n_estimators': 1742, 'learning_rate': 0.07532504351354768, 'subsample': 0.843084870845041, 'colsample_bytree': 0.8070262950060051, 'max_depth': 9, 'min_child_weight': 33, 'reg_lambda': 1.1750763744470042e-05, 'reg_alpha': 0.0242619223089714, 'lambda_l1': 4.164113811592045, 'lambda_l2': 9.253469175864733, 'num_leaves': 146}. Best is trial 142 with value: 0.8198282573242881.
# [I 2022-02-19 14:50:35,991] Trial 149 finished with value: 0.8149423077551408 and parameters: {'n_estimators': 1409, 'learning_rate': 0.0349817997017102, 'subsample': 0.8934750095677209, 'colsample_bytree': 0.7966302017426814, 'max_depth': 9, 'min_child_weight': 33, 'reg_lambda': 1.0242694779552714e-05, 'reg_alpha': 0.04395453319936861, 'lambda_l1': 6.937862608764139, 'lambda_l2': 5.31217298356388, 'num_leaves': 146}. Best is trial 142 with value: 0.8198282573242881.
# Number of finished trials: 150
# Best trial: {'n_estimators': 1211, 'learning_rate': 0.0655617061483102, 'subsample': 0.8424673374069434, 'colsample_bytree': 0.7456098558853268, 'max_depth': 9, 'min_child_weight': 28, 'reg_lambda': 1.748029886598557e-05, 'reg_alpha': 0.011816434352783945, 'lambda_l1': 3.342275961260333, 'lambda_l2': 9.28445946270099, 'num_leaves': 167}

# %% [markdown]
# # Results
#
# I'm still using test set to evaluate metrics like a confusion matrix, which is totally wrong. I should use training to evaluate all theses metrics with cross_val_predict().

# %%
from sklearn.model_selection import cross_val_predict
best_params= {'n_estimators': 1211, 'learning_rate': 0.0655617061483102, 'subsample': 0.8424673374069434, 'colsample_bytree': 0.7456098558853268, 'max_depth': 9, 'min_child_weight': 28, 'reg_lambda': 1.748029886598557e-05, 'reg_alpha': 0.011816434352783945, 'lambda_l1': 3.342275961260333, 'lambda_l2': 9.28445946270099, 'num_leaves': 167}


lgbm_clf = LGBMClassifier(random_state=seeds,**best_params)

final_pipeline = make_pipeline(preprocess, smoteen, lgbm_clf)

y_train_pred = cross_val_predict(final_pipeline, X, y,cv=cv)
# Out:
# [LightGBM] [Warning] lambda_l1 is set=3.342275961260333, reg_alpha=0.011816434352783945 will be ignored. Current value: lambda_l1=3.342275961260333
# [LightGBM] [Warning] lambda_l2 is set=9.28445946270099, reg_lambda=1.748029886598557e-05 will be ignored. Current value: lambda_l2=9.28445946270099
# [LightGBM] [Warning] lambda_l1 is set=3.342275961260333, reg_alpha=0.011816434352783945 will be ignored. Current value: lambda_l1=3.342275961260333
# [LightGBM] [Warning] lambda_l2 is set=9.28445946270099, reg_lambda=1.748029886598557e-05 will be ignored. Current value: lambda_l2=9.28445946270099
# [LightGBM] [Warning] lambda_l1 is set=3.342275961260333, reg_alpha=0.011816434352783945 will be ignored. Current value: lambda_l1=3.342275961260333
# [LightGBM] [Warning] lambda_l2 is set=9.28445946270099, reg_lambda=1.748029886598557e-05 will be ignored. Current value: lambda_l2=9.28445946270099
# [LightGBM] [Warning] lambda_l1 is set=3.342275961260333, reg_alpha=0.011816434352783945 will be ignored. Current value: lambda_l1=3.342275961260333
# [LightGBM] [Warning] lambda_l2 is set=9.28445946270099, reg_lambda=1.748029886598557e-05 will be ignored. Current value: lambda_l2=9.28445946270099
# [LightGBM] [Warning] lambda_l1 is set=3.342275961260333, reg_alpha=0.011816434352783945 will be ignored. Current value: lambda_l1=3.342275961260333
# [LightGBM] [Warning] lambda_l2 is set=9.28445946270099, reg_lambda=1.748029886598557e-05 will be ignored. Current value: lambda_l2=9.28445946270099

# %%
def evaluate_train(model):
    # Fit the model on training set
    model.fit(X, y)
    # Obtain the predictions
    preds = cross_val_predict(final_pipeline, X, y, cv=cv)
    # Predict probabilities
    #probs = model.predict_proba(X_test)
    # Print the F2-score, classification report and confusion matrix
    print("F2-score: {} " .format(round(fbeta_score(y, preds, beta=2), 3)))
    print(classification_report(y, preds))
    print(confusion_matrix(y, preds))

evaluate_train(final_pipeline)
# Out:
# [LightGBM] [Warning] lambda_l1 is set=3.342275961260333, reg_alpha=0.011816434352783945 will be ignored. Current value: lambda_l1=3.342275961260333
# [LightGBM] [Warning] lambda_l2 is set=9.28445946270099, reg_lambda=1.748029886598557e-05 will be ignored. Current value: lambda_l2=9.28445946270099
# [LightGBM] [Warning] lambda_l1 is set=3.342275961260333, reg_alpha=0.011816434352783945 will be ignored. Current value: lambda_l1=3.342275961260333
# [LightGBM] [Warning] lambda_l2 is set=9.28445946270099, reg_lambda=1.748029886598557e-05 will be ignored. Current value: lambda_l2=9.28445946270099
# [LightGBM] [Warning] lambda_l1 is set=3.342275961260333, reg_alpha=0.011816434352783945 will be ignored. Current value: lambda_l1=3.342275961260333
# [LightGBM] [Warning] lambda_l2 is set=9.28445946270099, reg_lambda=1.748029886598557e-05 will be ignored. Current value: lambda_l2=9.28445946270099
# [LightGBM] [Warning] lambda_l1 is set=3.342275961260333, reg_alpha=0.011816434352783945 will be ignored. Current value: lambda_l1=3.342275961260333
# [LightGBM] [Warning] lambda_l2 is set=9.28445946270099, reg_lambda=1.748029886598557e-05 will be ignored. Current value: lambda_l2=9.28445946270099
# [LightGBM] [Warning] lambda_l1 is set=3.342275961260333, reg_alpha=0.011816434352783945 will be ignored. Current value: lambda_l1=3.342275961260333
# [LightGBM] [Warning] lambda_l2 is set=9.28445946270099, reg_lambda=1.748029886598557e-05 will be ignored. Current value: lambda_l2=9.28445946270099
# F2-score: 0.82
#               precision    recall  f1-score   support
#
#            0       0.95      0.73      0.82      5405
#            1       0.58      0.92      0.71      2227
#
#     accuracy                           0.78      7632
#    macro avg       0.77      0.82      0.77      7632
# weighted avg       0.84      0.78      0.79      7632
#
# [[3922 1483]
#  [ 189 2038]]

# %%
y_scores = cross_val_predict(final_pipeline, X, y, cv=cv,method="predict_proba")
# Out:
# [LightGBM] [Warning] lambda_l1 is set=3.342275961260333, reg_alpha=0.011816434352783945 will be ignored. Current value: lambda_l1=3.342275961260333
# [LightGBM] [Warning] lambda_l2 is set=9.28445946270099, reg_lambda=1.748029886598557e-05 will be ignored. Current value: lambda_l2=9.28445946270099
# [LightGBM] [Warning] lambda_l1 is set=3.342275961260333, reg_alpha=0.011816434352783945 will be ignored. Current value: lambda_l1=3.342275961260333
# [LightGBM] [Warning] lambda_l2 is set=9.28445946270099, reg_lambda=1.748029886598557e-05 will be ignored. Current value: lambda_l2=9.28445946270099
# [LightGBM] [Warning] lambda_l1 is set=3.342275961260333, reg_alpha=0.011816434352783945 will be ignored. Current value: lambda_l1=3.342275961260333
# [LightGBM] [Warning] lambda_l2 is set=9.28445946270099, reg_lambda=1.748029886598557e-05 will be ignored. Current value: lambda_l2=9.28445946270099
# [LightGBM] [Warning] lambda_l1 is set=3.342275961260333, reg_alpha=0.011816434352783945 will be ignored. Current value: lambda_l1=3.342275961260333
# [LightGBM] [Warning] lambda_l2 is set=9.28445946270099, reg_lambda=1.748029886598557e-05 will be ignored. Current value: lambda_l2=9.28445946270099
# [LightGBM] [Warning] lambda_l1 is set=3.342275961260333, reg_alpha=0.011816434352783945 will be ignored. Current value: lambda_l1=3.342275961260333
# [LightGBM] [Warning] lambda_l2 is set=9.28445946270099, reg_lambda=1.748029886598557e-05 will be ignored. Current value: lambda_l2=9.28445946270099

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt
precisions, recalls, thresholds = precision_recall_curve(y, y_scores[:,1])

recall_90_precision = precisions[np.argmax(recalls >= 0.90)]
threshold_90_precision = thresholds[np.argmax(recalls >= 0.90)]

def plot_precision_recall_vs_threshold(precisions, recalls, thresholds):
    plt.plot(thresholds, precisions[:-1], "b--", label="Precision", linewidth=2)
    plt.plot(thresholds, recalls[:-1], "g-", label="Recall", linewidth=2)
    plt.legend(loc="center right", fontsize=16) # Not shown in the book
    plt.xlabel("Threshold", fontsize=16)        # Not shown
    plt.grid(True)                              # Not shown
    #plt.axis([-50000, 50000, 0, 1])             # Not shown

plt.figure(figsize=(8, 4))                                             
plot_precision_recall_vs_threshold(precisions, recalls, thresholds)
plt.show()

# %%
def plot_precision_vs_recall(precisions, recalls):
    plt.plot(recalls, precisions, "b-", linewidth=2)
    plt.xlabel("Recall", fontsize=16)
    plt.ylabel("Precision", fontsize=16)
    plt.axis([0, 1, 0, 1])
    plt.grid(True)

plt.figure(figsize=(8, 6))
plot_precision_vs_recall(precisions, recalls)
plt.plot([recall_90_precision, recall_90_precision], [0., 0.9], "r:")
plt.plot([0.0, recall_90_precision], [0.9, 0.9], "r:")
plt.plot([recall_90_precision], [0.9], "ro")
plt.show()

# %%
from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(y, y_scores[:,1])

def plot_roc_curve(fpr, tpr, label=None):
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.plot([0, 1], [0, 1], 'k--') # dashed diagonal
    plt.axis([0, 1, 0, 1])                                    # Not shown in the book
    plt.xlabel('False Positive Rate (Fall-Out)', fontsize=16) # Not shown
    plt.ylabel('True Positive Rate (Recall)', fontsize=16)    # Not shown
    plt.grid(True)                                            # Not shown

plt.figure(figsize=(8, 6))                                    # Not shown
plot_roc_curve(fpr, tpr)
fpr_90 = fpr[np.argmax(tpr >= recall_90_precision)]           # Not shown
plt.plot([fpr_90, fpr_90], [0., recall_90_precision], "r:")   # Not shown
plt.plot([0.0, fpr_90], [recall_90_precision, recall_90_precision], "r:")  # Not shown
plt.plot([fpr_90], [recall_90_precision], "ro")               # Not shown                                  # Not shown
plt.show()

# %%
# Reassign loan status based on the threshold
df_val = pd.DataFrame(y_scores)

df_val['pred_1'] = df_val[1].apply(lambda x: 1 if x > recall_90_precision else 0)

# Print the classification report
print("F2-score: {} " .format(round(fbeta_score(y, y_train_pred, beta=2), 3)))
print(classification_report(y, df_val['pred_1']))
print(confusion_matrix(y, df_val[['pred_1']]))
# Out:
# F2-score: 0.82
#               precision    recall  f1-score   support
#
#            0       0.97      0.64      0.77      5405
#            1       0.52      0.95      0.68      2227
#
#     accuracy                           0.73      7632
#    macro avg       0.75      0.80      0.72      7632
# weighted avg       0.84      0.73      0.74      7632
#
# [[3472 1933]
#  [ 104 2123]]

# %% [markdown]
# ## Final evaluation

# %%
def evaluate(model):
    # Fit the model on training set
    model.fit(X, y)
    # Obtain the predictions
    preds = model.predict(X_test)
    # Predict probabilities
    #probs = model.predict_proba(X_test)
    # Print the F2-score, classification report and confusion matrix
    print("F2-score: {} " .format(round(fbeta_score(y_test, preds, beta=2), 3)))
    print(classification_report(y_test, preds))
    ConfusionMatrixDisplay.from_estimator(final_pipeline, X_test, y_test)

evaluate(final_pipeline)
# Out:
# [LightGBM] [Warning] lambda_l1 is set=3.342275961260333, reg_alpha=0.011816434352783945 will be ignored. Current value: lambda_l1=3.342275961260333
# [LightGBM] [Warning] lambda_l2 is set=9.28445946270099, reg_lambda=1.748029886598557e-05 will be ignored. Current value: lambda_l2=9.28445946270099
# F2-score: 0.834
#               precision    recall  f1-score   support
#
#            0       0.97      0.72      0.82      1351
#            1       0.58      0.94      0.71       557
#
#     accuracy                           0.78      1908
#    macro avg       0.77      0.83      0.77      1908
# weighted avg       0.85      0.78      0.79      1908

# %%
def get_results(model):
    # Fit the model on training set
    model.fit(X, y)
    # Obtain the predictions
    preds = model.predict(X_test)
    # Predict probabilities
    probs = model.predict_proba(X_test)
    return preds, probs

preds, probs = get_results(final_pipeline)
# Out:
# [LightGBM] [Warning] lambda_l1 is set=3.342275961260333, reg_alpha=0.011816434352783945 will be ignored. Current value: lambda_l1=3.342275961260333
# [LightGBM] [Warning] lambda_l2 is set=9.28445946270099, reg_lambda=1.748029886598557e-05 will be ignored. Current value: lambda_l2=9.28445946270099

# %%
# Create pred column on test set
df_test = test.copy()
df_test["pred_left"] = preds
df_test["prob_left"] = probs[:,1]
df_test["pred_mod"] = df_test["prob_left"].apply(lambda x: 1 if x > recall_90_precision else 0)

# %%
from sklearn.metrics import ConfusionMatrixDisplay
print(classification_report(y_test, df_test["pred_mod"]))
print(confusion_matrix(y_test, df_test["pred_mod"]))
ConfusionMatrixDisplay.from_estimator(final_pipeline, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.63      0.77      1351
#            1       0.52      0.96      0.67       557
#
#     accuracy                           0.73      1908
#    macro avg       0.75      0.80      0.72      1908
# weighted avg       0.84      0.73      0.74      1908
#
# [[851 500]
#  [ 21 536]]

# %% [markdown]
# How our model is detecting those who churn?
#
# Our model detect churned employees 95% of the time.
#
# 26 employees where predicted non-churned but actually churned.
#
# Who are these people?

# %% [markdown]
# Next. Use pickle to dump the model for re-use later.

# %%
from sklearn.inspection import permutation_importance
result = permutation_importance(final_pipeline, X_test, y_test, n_repeats=10,
                                random_state=seeds, n_jobs=2)

sorted_idx = result.importances_mean.argsort()
plt.boxplot(result.importances[sorted_idx].T, vert=False, labels=X.columns[sorted_idx])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23483682790>,
#   <matplotlib.lines.Line2D at 0x23483682a60>,
#   <matplotlib.lines.Line2D at 0x23483690bb0>,
#   <matplotlib.lines.Line2D at 0x23483690e80>,
#   <matplotlib.lines.Line2D at 0x2348369dfa0>,
#   <matplotlib.lines.Line2D at 0x234836aa2b0>,
#   <matplotlib.lines.Line2D at 0x234836b33d0>,
#   <matplotlib.lines.Line2D at 0x234836b36a0>,
#   <matplotlib.lines.Line2D at 0x234836c47c0>,
#   <matplotlib.lines.Line2D at 0x234836c4a90>,
#   <matplotlib.lines.Line2D at 0x234836d1bb0>,
#   <matplotlib.lines.Line2D at 0x234836d1e80>,
#   <matplotlib.lines.Line2D at 0x234836dffa0>,
#   <matplotlib.lines.Line2D at 0x234836eb2b0>,
#   <matplotlib.lines.Line2D at 0x234836fa3d0>,
#   <matplotlib.lines.Line2D at 0x234836fa6a0>,
#   <matplotlib.lines.Line2D at 0x234837067c0>,
#   <matplotlib.lines.Line2D at 0x23483706ac0>],
#  'caps': [<matplotlib.lines.Line2D at 0x23483682d30>,
#   <matplotlib.lines.Line2D at 0x23483690040>,
#   <matplotlib.lines.Line2D at 0x2348369d190>,
#   <matplotlib.lines.Line2D at 0x2348369d460>,
#   <matplotlib.lines.Line2D at 0x234836aa580>,
#   <matplotlib.lines.Line2D at 0x234836aa850>,
#   <matplotlib.lines.Line2D at 0x234836b3970>,
#   <matplotlib.lines.Line2D at 0x234836b3c40>,
#   <matplotlib.lines.Line2D at 0x234836c4d60>,
#   <matplotlib.lines.Line2D at 0x234836d1070>,
#   <matplotlib.lines.Line2D at 0x234836df190>,
#   <matplotlib.lines.Line2D at 0x234836df460>,
#   <matplotlib.lines.Line2D at 0x234836eb580>,
#   <matplotlib.lines.Line2D at 0x234836eb850>,
#   <matplotlib.lines.Line2D at 0x234836fa970>,
#   <matplotlib.lines.Line2D at 0x234836fac40>,
#   <matplotlib.lines.Line2D at 0x23483706d90>,
#   <matplotlib.lines.Line2D at 0x234837130a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x234836824c0>,
#   <matplotlib.lines.Line2D at 0x234836908b0>,
#   <matplotlib.lines.Line2D at 0x2348369dcd0>,
#   <matplotlib.lines.Line2D at 0x234836b3100>,
#   <matplotlib.lines.Line2D at 0x234836c44f0>,
#   <matplotlib.lines.Line2D at 0x234836d18e0>,
#   <matplotlib.lines.Line2D at 0x234836dfcd0>,
#   <matplotlib.lines.Line2D at 0x234836fa100>,
#   <matplotlib.lines.Line2D at 0x234837064f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x23483690310>,
#   <matplotlib.lines.Line2D at 0x2348369d730>,
#   <matplotlib.lines.Line2D at 0x234836aab20>,
#   <matplotlib.lines.Line2D at 0x234836b3f10>,
#   <matplotlib.lines.Line2D at 0x234836d1340>,
#   <matplotlib.lines.Line2D at 0x234836df730>,
#   <matplotlib.lines.Line2D at 0x234836ebb20>,
#   <matplotlib.lines.Line2D at 0x234836faf10>,
#   <matplotlib.lines.Line2D at 0x23483713370>],
#  'fliers': [<matplotlib.lines.Line2D at 0x234836905e0>,
#   <matplotlib.lines.Line2D at 0x2348369da00>,
#   <matplotlib.lines.Line2D at 0x234836aadf0>,
#   <matplotlib.lines.Line2D at 0x234836c4220>,
#   <matplotlib.lines.Line2D at 0x234836d1610>,
#   <matplotlib.lines.Line2D at 0x234836dfa00>,
#   <matplotlib.lines.Line2D at 0x234836ebdf0>,
#   <matplotlib.lines.Line2D at 0x23483706220>,
#   <matplotlib.lines.Line2D at 0x23483713640>],
#  'means': []}

# %%
import eli5
from eli5.sklearn import PermutationImportance

perm = PermutationImportance(final_pipeline, random_state=seeds).fit(X, y)
eli5.show_weights(perm, feature_names = X_train.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19368/2015856699.py in <module>
# ----> 1 import eli5
#       2 from eli5.sklearn import PermutationImportance
#       3
#       4 perm = PermutationImportance(final_pipeline, random_state=seeds).fit(X, y)
#       5 eli5.show_weights(perm, feature_names = X_train.columns.tolist())
#
# C:\ProgramData\Anaconda3\envs\env_full\lib\site-packages\eli5\__init__.py in <module>
#       4 __version__ = '0.11.0'
#       5
# ----> 6 from .formatters import (
#       7     format_as_html,
#       8     format_html_styles,
#
# C:\ProgramData\Anaconda3\envs\env_full\lib\site-packages\eli5\formatters\__init__.py in <module>
#       7
#       8 from .text import format_as_text
# ----> 9 from .html import format_as_html, format_html_styles
#      10 try:
#      11     from .as_dataframe import (
#
# C:\ProgramData\Anaconda3\envs\env_full\lib\site-packages\eli5\formatters\html.py in <module>
#       5
#       6 import numpy as np
# ----> 7 from jinja2 import Environment, PackageLoader
#       8
#       9 from eli5 import _graphviz
#
# C:\ProgramData\Anaconda3\envs\env_full\lib\site-packages\jinja2\__init__.py in <module>
#      10 from .bccache import FileSystemBytecodeCache
#      11 from .bccache import MemcachedBytecodeCache
# ---> 12 from .environment import Environment
#      13 from .environment import Template
#      14 from .exceptions import TemplateAssertionError
#
# C:\ProgramData\Anaconda3\envs\env_full\lib\site-packages\jinja2\environment.py in <module>
#      23 from .compiler import CodeGenerator
#      24 from .compiler import generate
# ---> 25 from .defaults import BLOCK_END_STRING
#      26 from .defaults import BLOCK_START_STRING
#      27 from .defaults import COMMENT_END_STRING
#
# C:\ProgramData\Anaconda3\envs\env_full\lib\site-packages\jinja2\defaults.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2 from ._compat import range_type
# ----> 3 from .filters import FILTERS as DEFAULT_FILTERS  # noqa: F401
#       4 from .tests import TESTS as DEFAULT_TESTS  # noqa: F401
#       5 from .utils import Cycler
#
# C:\ProgramData\Anaconda3\envs\env_full\lib\site-packages\jinja2\filters.py in <module>
#      11 from markupsafe import escape
#      12 from markupsafe import Markup
# ---> 13 from markupsafe import soft_unicode
#      14
#      15 from ._compat import abc
#
# ImportError: cannot import name 'soft_unicode' from 'markupsafe' (C:\ProgramData\Anaconda3\envs\env_full\lib\site-packages\markupsafe\__init__.py)
